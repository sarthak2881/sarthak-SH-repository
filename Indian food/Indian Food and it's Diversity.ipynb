# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('indian_food.csv')

# %%
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
df.describe(include=object)
# Out:
#               name              ingredients        diet flavor_profile  \
# count          255                      255         255            255
# unique         255                      252           2              5
# top     Balu shahi  Gram flour, ghee, sugar  vegetarian          spicy
# freq             1                        2         226            133
#
#              course    state region
# count           255      255    254
# unique            4       25      7
# top     main course  Gujarat   West
# freq            129       35     74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
df.head(15)
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
df.sample()
# Out:
#             name                                        ingredients  \
# 99  Litti chokha  Wheat flour, roasted gram flour, tomato, nigel...
#
#           diet  prep_time  cook_time flavor_profile       course  state region
# 99  vegetarian         45         60          spicy  main course  Bihar  North

# %%
df['flavor_profile'].value_counts()
# Out:
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: flavor_profile, dtype: int64

# %%
df.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
np.where(df['region'].isnull())
# Out:
# (array([110], dtype=int64),)

# %%
df.loc[df['region'].isna()]
# Out:
#          name                                        ingredients        diet  \
# 110  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state region
# 110         10         25          sweet  dessert  Uttar Pradesh    NaN

# %%
df.loc[df['flavor_profile']=='-1'].head(14)
# Out:
#               name                                        ingredients  \
# 78         Chapati  Whole wheat flour, olive oil, hot water, all p...
# 104           Naan           Whole wheat flour, honey, butter, garlic
# 116          Rongi  Garam masala powder, tomato, kasuri methi, cin...
# 131          Kanji     Carrot, yellow mustard, red chilli, black salt
# 145        Pachadi  Coconut oil, cucumber, curd, curry leaves, mus...
# 146      Paniyaram  Yogurt, ginger, curry leaves, baking soda, gre...
# 150  Paruppu sadam  Arhar dal, sambar powder, tomato, curry leaves...
# 153     Puli sadam  Urad dal, lemon, tamarind, cooked rice, curry ...
# 155          Puttu            Brown rice flour, sugar, grated coconut
# 157        Sandige  Thin rice flakes, black sesame seeds, curry le...
# 158          Sevai                     Sevai, parboiled rice, steamer
# 159   Thayir sadam  Urad dal, curd, sesame oil, ginger, curry leav...
# ...

# %%
df.loc[df['diet'].isnull()]
# Out:
#          name                                        ingredients        diet  \
# 110  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state region
# 110         10         25          sweet  dessert  Uttar Pradesh    NaN

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[(df['prep_time']<=10) & (df['cook_time']<=30) & (df['flavor_profile']=='sweet')]
# Out:
#                    name                                        ingredients  \
# 7            Kaju katli                     Cashews, ghee, cardamom, sugar
# 11                Lassi                          Yogurt, milk, nuts, sugar
# 13                Petha  Firm white pumpkin, sugar, kitchen lime, alum ...
# 16               Sheera                         Semolina, ghee, nuts, milk
# 17              Singori                           Khoa, coconut, molu leaf
# 39               Chikki                                   Peanuts, jaggery
# 42              Gavvalu            Rice flour, sugar, salt, ghee, semolina
# 43       Kakinada khaja                                 Wheat flour, sugar
# 44      Kuzhi paniyaram                                Black lentils, rice
# 45           Mysore pak  Besan flour, semolina, mung bean, jaggery, coc...
# 47        Palathalikalu                                   Rice flour, milk
# ...

# %%
cor= df.corr()

# %%
sns.heatmap(cor)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df , x ='course' , y = 'cook_time')
# Out:
# <AxesSubplot:xlabel='course', ylabel='cook_time'>

# %%
pd.DataFrame(df.groupby(['state']).region.unique())
# Out:
#                              region
# state
# -1               [-1, North, South]
# Andhra Pradesh              [South]
# Assam                  [North East]
# Bihar                       [North]
# Chhattisgarh              [Central]
# Goa                          [West]
# Gujarat                      [West]
# Haryana                     [North]
# Jammu & Kashmir             [North]
# Karnataka                   [South]
# Kerala                      [South]
# Madhya Pradesh            [Central]
# Maharashtra                  [West]
# Manipur                [North East]
# NCT of Delhi                [North]
# Nagaland               [North East]
# Odisha                       [East]
# Punjab                      [North]
# Rajasthan                    [West]
# Tamil Nadu                  [South]
# Telangana                   [South]
# Tripura                [North East]
# Uttar Pradesh          [North, nan]
# Uttarakhand                 [North]
# West Bengal                  [East]

# %%
pd.DataFrame(df.groupby(['region']).state.unique())
# Out:
#                                                         state
# region
# -1                                                       [-1]
# Central                        [Chhattisgarh, Madhya Pradesh]
# East                                    [West Bengal, Odisha]
# North       [Punjab, Uttar Pradesh, Uttarakhand, Bihar, NC...
# North East                [Assam, Tripura, Manipur, Nagaland]
# South       [Andhra Pradesh, Karnataka, Telangana, Kerala,...
# West                   [Rajasthan, Maharashtra, Gujarat, Goa]

# %%
df.loc[df['cook_time']<29,['name','diet','prep_time','cook_time','flavor_profile']]
# Out:
#            name        diet  prep_time  cook_time flavor_profile
# 0    Balu shahi  vegetarian         45         25          sweet
# 7    Kaju katli  vegetarian         10         20          sweet
# 11        Lassi  vegetarian          5          5          sweet
# 14       Phirni  vegetarian         30         20          sweet
# 16       Sheera  vegetarian         10         25          sweet
# ..          ...         ...        ...        ...            ...
# 246      Payokh  vegetarian         -1         -1          sweet
# 248    Red Rice  vegetarian         -1         -1             -1
# 249      Shukto  vegetarian         10         20          spicy
# 252      Shufta  vegetarian         -1         -1          sweet
# 254      Pinaca  vegetarian         -1         -1          sweet
#
# [100 rows x 5 columns]

# %%
filt = df.prep_time > 60 
a = df.loc[filt, ['name', 'prep_time', 'cook_time' , 'diet']].sort_values(by='prep_time', ascending=False)
a.set_index(['name'], inplace=True)
a
# Out:
#                      prep_time  cook_time            diet
# name
# Pindi chana                500        120      vegetarian
# Puttu                      495         40      vegetarian
# Misti doi                  480         30      vegetarian
# Idli                       360         90      vegetarian
# Masala Dosa                360         90      vegetarian
# Dosa                       360         90      vegetarian
# Tandoori Fish Tikka        240         30  non vegetarian
# Poornalu                   240         60      vegetarian
# Chak Hao Kheer             240         45      vegetarian
# Tandoori Chicken           240         30  non vegetarian
# Ras malai                  180         60      vegetarian
# Obbattu holige             180         60      vegetarian
# Attu                       150         25      vegetarian
# Idiappam                   120         30      vegetarian
# Sevai                      120         30      vegetarian
# ...

# %%
plt.figure(figsize=(16, 8))
sns.barplot(data=a, x=a.index, y='prep_time', color="#54436B", label="Preparation Time")
sns.barplot(data=a, x=a.index, y='cook_time', color="#50CB93", label="Cooking Time")

plt.xticks(rotation=90)

plt.xlabel("Name of Dish")
plt.ylabel("Time in minutes")
plt.title("Total prepartion and cooking time taken by dish.")

plt.legend()
plt.show()

# %%
df['Total_Time(in min)']=df['prep_time']+df['cook_time']

# %%
df.head(3)
# Out:
#              name                                   ingredients        diet  \
# 0      Balu shahi               Maida flour, yogurt, oil, sugar  vegetarian
# 1          Boondi                       Gram flour, ghee, sugar  vegetarian
# 2  Gajar ka halwa  Carrots, milk, sugar, ghee, cashews, raisins  vegetarian
#
#    prep_time  cook_time flavor_profile   course        state region  \
# 0         45         25          sweet  dessert  West Bengal   East
# 1         80         30          sweet  dessert    Rajasthan   West
# 2         15         60          sweet  dessert       Punjab  North
#
#    Total_Time  Total_Time(in min)
# 0          70                  70
# 1         110                 110
# 2          75                  75

# %%
df.drop(['Total_Time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region  Total_Time(in min)
# 0   East                  70
# 1   West                 110
# ...
